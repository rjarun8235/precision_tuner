# %%
# !pip install numpy pandas tqdm requests datasets matplotlib seaborn --q

# %%
# !nvidia-smi
# Out:
# Sun May 25 12:52:12 2025
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 565.57.01              Driver Version: 565.57.01      CUDA Version: 12.7     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  NVIDIA GeForce RTX 3090        Off |   00000000:05:00.0 Off |                  N/A |
# | 30%   42C    P0            106W /  350W |       1MiB /  24576MiB |      0%      Default |
# |                                         |                        |                  N/A |
# ...

# %%
# !curl -fsSL https://ollama.com/install.sh | sh
# Out:
# >>> Installing ollama to /usr/local
# >>> Downloading Linux amd64 bundle
# ######################################################################## 100.0%                        1.5%                                               14.7%                       17.0%                                        21.5%                    38.7% 39.5%                                 51.6%                  52.4%                     53.1%          55.5%        77.7%###################################        92.0%
# >>> Creating ollama user...
# >>> Adding ollama user to render group...
# >>> Adding ollama user to video group...
# >>> Adding current user to ollama group...
# >>> Creating ollama systemd service...
# >>> Enabling and starting ollama service...
# Created symlink /etc/systemd/system/default.target.wants/ollama.service → /etc/systemd/system/ollama.service.
# >>> NVIDIA GPU installed.

# %%
# !ollama pull gemma3:1b
# Out:
# pulling manifest ⠋ pulling manifest ⠙ pulling manifest ⠹ pulling manifest ⠸ pulling manifest ⠼ pulling manifest ⠴ pulling manifest
# pulling 7cd4618c1faf: 100% ▕██████████████████▏ 815 MB
# pulling e0a42594d802: 100% ▕██████████████████▏  358 B
# pulling dd084c7d92a3: 100% ▕██████████████████▏ 8.4 KB
# pulling 3116c5225075: 100% ▕██████████████████▏   77 B
# pulling 120007c81bf8: 100% ▕██████████████████▏  492 B
# verifying sha256 digest
# writing manifest
# success

# %%
# !ollama pull qwen3:1.7b
# Out:
# pulling manifest ⠋ pulling manifest ⠙ pulling manifest ⠹ pulling manifest ⠸ pulling manifest ⠼ pulling manifest ⠴ pulling manifest ⠦ pulling manifest ⠧ pulling manifest ⠇ pulling manifest ⠏ pulling manifest ⠋ pulling manifest
# pulling 3d0b790534fe:   0% ▕                  ▏ 174 KB/1.4 GB                  pulling manifest
# pulling 3d0b790534fe:   1% ▕                  ▏ 9.2 MB/1.4 GB                  pulling manifest
# pulling 3d0b790534fe:   1% ▕                  ▏  12 MB/1.4 GB                  pulling manifest
# pulling 3d0b790534fe:   2% ▕                  ▏  25 MB/1.4 GB                  pulling manifest
# pulling 3d0b790534fe:   3% ▕                  ▏  41 MB/1.4 GB                  pulling manifest
# pulling 3d0b790534fe:   4% ▕                  ▏  49 MB/1.4 GB                  pulling manifest
# pulling 3d0b790534fe:   5% ▕                  ▏  64 MB/1.4 GB                  pulling manifest
# ...

# %%
# !ollama list
# Out:
# NAME          ID              SIZE      MODIFIED
# qwen3:1.7b    458ce03a2187    1.4 GB    Less than a second ago
# gemma3:1b     8648f39daa8f    815 MB    22 seconds ago

# %%
# !ollama pull deepseek-r1:1.5b
# Out:
# pulling manifest ⠋ pulling manifest ⠙ pulling manifest ⠹ pulling manifest ⠸ pulling manifest ⠼ pulling manifest ⠴ pulling manifest ⠦ pulling manifest ⠧ pulling manifest ⠇ pulling manifest ⠏ pulling manifest ⠋ pulling manifest
# pulling aabd4debf0c8:   1% ▕                  ▏ 8.9 MB/1.1 GB                  pulling manifest
# pulling aabd4debf0c8:   1% ▕                  ▏  13 MB/1.1 GB                  pulling manifest
# pulling aabd4debf0c8:   2% ▕                  ▏  26 MB/1.1 GB                  pulling manifest
# pulling aabd4debf0c8:   4% ▕                  ▏  40 MB/1.1 GB                  pulling manifest
# pulling aabd4debf0c8:   4% ▕                  ▏  48 MB/1.1 GB                  pulling manifest
# pulling aabd4debf0c8:   6% ▕                  ▏  62 MB/1.1 GB                  pulling manifest
# pulling aabd4debf0c8:   7% ▕█                 ▏  75 MB/1.1 GB                  pulling manifest
# ...

# %%
# !ollama pull llama3.2:1b
# Out:
# pulling manifest ⠋ pulling manifest ⠙ pulling manifest ⠹ pulling manifest ⠸ pulling manifest ⠼ pulling manifest ⠴ pulling manifest ⠦ pulling manifest ⠧ pulling manifest ⠇ pulling manifest ⠏ pulling manifest ⠋ pulling manifest
# pulling 74701a8c35f6:   1% ▕                  ▏ 7.1 MB/1.3 GB                  pulling manifest
# pulling 74701a8c35f6:   1% ▕                  ▏  11 MB/1.3 GB                  pulling manifest
# pulling 74701a8c35f6:   2% ▕                  ▏  25 MB/1.3 GB                  pulling manifest
# pulling 74701a8c35f6:   3% ▕                  ▏  38 MB/1.3 GB                  pulling manifest
# pulling 74701a8c35f6:   3% ▕                  ▏  44 MB/1.3 GB                  pulling manifest
# pulling 74701a8c35f6:   4% ▕                  ▏  55 MB/1.3 GB                  pulling manifest
# pulling 74701a8c35f6:   5% ▕                  ▏  69 MB/1.3 GB                  pulling manifest
# ...

# %%
# !ollama pull phi3:3.8b
# Out:
# pulling manifest ⠋ pulling manifest ⠙ pulling manifest ⠹ pulling manifest ⠸ pulling manifest ⠼ pulling manifest ⠴ pulling manifest ⠦ pulling manifest ⠧ pulling manifest ⠇ pulling manifest ⠏ pulling manifest ⠋ pulling manifest
# pulling 633fc5be925f:   0% ▕                  ▏ 1.0 MB/2.2 GB                  pulling manifest
# pulling 633fc5be925f:   0% ▕                  ▏ 6.6 MB/2.2 GB                  pulling manifest
# pulling 633fc5be925f:   1% ▕                  ▏  16 MB/2.2 GB                  pulling manifest
# pulling 633fc5be925f:   1% ▕                  ▏  28 MB/2.2 GB                  pulling manifest
# pulling 633fc5be925f:   2% ▕                  ▏  47 MB/2.2 GB                  pulling manifest
# pulling 633fc5be925f:   2% ▕                  ▏  53 MB/2.2 GB                  pulling manifest
# pulling 633fc5be925f:   3% ▕                  ▏  66 MB/2.2 GB                  pulling manifest
# ...

# %%
# !ollama list
# Out:
# NAME                ID              SIZE      MODIFIED
# phi3:3.8b           4f2222927938    2.2 GB    Less than a second ago
# llama3.2:1b         baf6a787fdff    1.3 GB    32 seconds ago
# deepseek-r1:1.5b    a42b25d8c10a    1.1 GB    55 seconds ago
# qwen3:1.7b          458ce03a2187    1.4 GB    About a minute ago
# gemma3:1b           8648f39daa8f    815 MB    About a minute ago

# %%
! ollama serve
# Out:
# Couldn't find '/home/user/.ollama/id_ed25519'. Generating new private key.
# Your new public key is:
#
# ssh-ed25519 AAAAC3NzaC1lZDI1NTE5AAAAIE9RWsi3GyD1ZjWoVP/WG7/YNc8bhQx1oRf0kfxqYWtI
#
# Error: listen tcp 127.0.0.1:11434: bind: address already in use

# %%
# !pwd
# Out:
# /home/user

# %%
# !ls
# Out:
# precision_runner.ipynb	precision_tuner  precision_tuner.log

# %%
# !python precision_tuner/main.py
# Out:
# 2025-05-25 13:45:34,780 - numexpr.utils - INFO - NumExpr defaulting to 8 threads.
# 2025-05-25 13:45:35,413 - datasets - INFO - PyTorch version 2.5.1 available.
# 2025-05-25 13:45:35,414 - datasets - INFO - TensorFlow version 2.18.0 available.
# 2025-05-25 13:45:37,377 - PrecisionTuner.Main - INFO - PRECISIONTUNER: DATASET GENERATION
# 2025-05-25 13:45:37,377 - PrecisionTuner.Main - INFO - ============================================================
# 2025-05-25 13:45:37,377 - PrecisionTuner.Main - INFO - Target: Instruction-following dataset generation
# 2025-05-25 13:45:37,377 - PrecisionTuner.Main - INFO - Innovation: Systematic constraint-based instruction dataset
# 2025-05-25 13:45:37,377 - PrecisionTuner.Main - INFO - Optimized for: RTX 3090 (24GB VRAM)
# 2025-05-25 13:45:37,377 - PrecisionTuner.Main - INFO - Initializing PrecisionTuner...
# 2025-05-25 13:45:37,387 - PrecisionTuner - INFO - PrecisionTuner Memory-Optimized Setup
# ...

# %%
# !ollama list
# Out:
# NAME                ID              SIZE      MODIFIED
# phi3:3.8b           4f2222927938    2.2 GB    37 minutes ago
# llama3.2:1b         baf6a787fdff    1.3 GB    38 minutes ago
# deepseek-r1:1.5b    a42b25d8c10a    1.1 GB    38 minutes ago
# qwen3:1.7b          458ce03a2187    1.4 GB    39 minutes ago
# gemma3:1b           8648f39daa8f    815 MB    39 minutes ago

# %%
# !nvidia-smi
# Out:
# Sun May 25 15:55:17 2025
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 565.57.01              Driver Version: 565.57.01      CUDA Version: 12.7     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  NVIDIA GeForce RTX 3090        Off |   00000000:05:00.0 Off |                  N/A |
# |  0%   32C    P8             14W /  350W |       4MiB /  24576MiB |      0%      Default |
# |                                         |                        |                  N/A |
# ...

# %%
# !python ./precision_tuner/main.py
# Out:
# 2025-05-25 17:24:55,094 - numexpr.utils - INFO - NumExpr defaulting to 8 threads.
# 2025-05-25 17:24:55,457 - datasets - INFO - PyTorch version 2.5.1 available.
# 2025-05-25 17:24:55,458 - datasets - INFO - TensorFlow version 2.18.0 available.
# 2025-05-25 17:24:55,710 - PrecisionTuner.Main - INFO - PRECISIONTUNER: CONSTRAINT PROGRESSION + ROUND-ROBIN
# 2025-05-25 17:24:55,710 - PrecisionTuner.Main - INFO - ============================================================
# 2025-05-25 17:24:55,710 - PrecisionTuner.Main - INFO - Strategy: Round-robin assignment (sample_index % 5)
# 2025-05-25 17:24:55,710 - PrecisionTuner.Main - INFO - Learning: Constraint progression (L1→L2→L3→L4)
# 2025-05-25 17:24:55,710 - PrecisionTuner.Main - INFO - L1: Single constraints (length OR format)
# 2025-05-25 17:24:55,710 - PrecisionTuner.Main - INFO - L2: Dual constraints (length + forbidden)
# 2025-05-25 17:24:55,710 - PrecisionTuner.Main - INFO - L3: Triple constraints (format + length + forbidden)
# ...

# %%
# !ollama list
# Out:
# NAME           ID              SIZE      MODIFIED
# phi3:3.8b      4f2222927938    2.2 GB    3 hours ago
# llama3.2:1b    baf6a787fdff    1.3 GB    3 hours ago
# gemma3:1b      8648f39daa8f    815 MB    3 hours ago

# %%
# !ollama rm qwen3:1.7b
# Out:
# deleted 'qwen3:1.7b'

# %%
# !ollama --help
# Out:
# Large language model runner
#
# Usage:
#   ollama [flags]
#   ollama [command]
#
# Available Commands:
#   serve       Start ollama
#   create      Create a model from a Modelfile
#   show        Show information for a model
#   run         Run a model
#   stop        Stop a running model
#   pull        Pull a model from a registry
#   push        Push a model to a registry
#   list        List models
#   ps          List running models
#   cp          Copy a model
#   rm          Remove a model
#   help        Help about any command
#
# Flags:
#   -h, --help      help for ollama
#   -v, --version   Show version information
#
# Use "ollama [command] --help" for more information about a command.

# %%
# !ollama rm deepseek-r1:1.5b
# Out:
# deleted 'deepseek-r1:1.5b'

# %%
# !zip -r PrecisionTuner.zip precision_tuner
# Out:
# /bin/bash: line 1: zip: command not found
